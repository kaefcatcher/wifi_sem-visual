# %% [markdown]
# # Ну и ну
# Привет, всякому кого судьба занесет в такое место в жизни, в котором ему захочется глядеть в этот notebook. В этой серии notebook-ов я постараюсь сделать запечатлеть полный курс по построениям сетей WiFi с частями семинаров и лекций, чтобы собрать все материалы в одном месте.

# %% [markdown]
# ## Первая практическая задачка:
# Есть несколько островов на расстоянии 300 км друг от друга. Тянуть кабели дорого, поэтому нужно строить систему беспроводной связи. **Основная задача**: Обеспечить гарантированную доставку пакетов со нескольких терминалов на центральный компьютер. Делим ли очередь передачи на несколько очередей, если:
# * Пользовательские данные поступают на центральный компьютер, образуя пуассоновский поток:
# $$ P(k; \lambda) = \frac{\lambda^k e^{-\lambda}}{k!} $$
#     * P(k;λ) — вероятность того, что случится k событий
#     * λ — среднее количество событий за фиксированный интервал времени;
#     * k — количество событий;
#     * e — основание натурального логарифма (примерно равно 2.71828);
#
# * Отброшенные из-за ошибок передачи пакеты передаются повторно, также образуя пуассоновский поток
#
# * Все пакеты имеют одинаковую длину и передаются одинаковое время
#
# * В сети находится бесконечное количество удаленных терминалов (то есть если некий терминал уже передает данные, это никак не влияет на вероятность передачи данных другими терминалами)

# %% [markdown]
# ### Доказательство о разделении трафика в сети ALOHA на несколько очередей
#
# #### Введение
#
# В ALOHA, системе случайного доступа, пакеты передаются в сеть с возможностью коллизий. Важно определить, может ли трафик быть эффективно разделён на несколько очередей для предотвращения перегрузки.
#
# #### Основные положения
#
# - Пусть λ — интенсивность входящего трафика в сеть (среднее количество пакетов в секунду).
# - Пусть \( G \) — нормированная нагрузка сети, выражающая среднее количество попыток передачи пакетов в единицу времени.
# - Успешная передача пакетов возможна только тогда, когда не происходит коллизий. Вероятность того, что пакет передан без коллизий, выражается как    $$P_{\text{успех}} = e^{-G}$$
#
# #### Утверждение
#
# **Если трафик не разделяется на несколько очередей, вероятность успеха передачи уменьшается экспоненциально с увеличением нагрузки.**
#
# #### Доказательство
#
# 1. Пусть трафик в сети не разделён и все пакеты конкурируют за доступ к одному каналу. В этом случае вероятность успешной передачи пакета в ALOHA определяется как:
#
#    $$
#    P_{\text{успех}} = e^{-G}
#    $$
#
# 2. Если средняя нагрузка \( G \) увеличивается из-за того, что количество передаваемых пакетов растёт, то вероятность успешной передачи уменьшается по экспоненциальному закону:
#
#    $$
#    P_{\text{успех}} \to 0 \quad \text{при} \quad G \to \infty
#    $$
#
#    Следовательно, сеть без разделения на очереди становится неэффективной при большой нагрузке, поскольку большая часть пакетов будет теряться из-за коллизий.
#
# 3. Теперь рассмотрим сценарий, когда трафик разделяется на несколько очередей, каждая из которых обрабатывает часть трафика. Пусть каждая очередь передаёт трафик с нагрузкой $$G_i ,    i = 1, 2, \dots, n$$ — номер очереди, и общая нагрузка:
#
#    $$
#    G = \sum_{i=1}^{n} G_i
#    $$
#
#    В этом случае вероятность успеха передачи пакета в каждой отдельной очереди:
#
#    $$
#    P_{\text{успех},i} = e^{-G_i}
#    $$
#
# 4. При разделении трафика вероятность успешной передачи пакета для каждого из потоков увеличивается, поскольку нагрузка \( G_i \) в каждой отдельной очереди меньше, чем общая нагрузка \( G \) при отсутствии разделения:
#
#    $$
#    P_{\text{успех}} = 1 - \prod_{i=1}^{n} (1 - P_{\text{успех},i})
#    $$
#
#    При разумном разделении нагрузки вероятность успеха становится выше.
#
# #### Заключение
#
# Разделение трафика в сети ALOHA на несколько очередей приводит к увеличению вероятности успешной передачи пакетов, особенно при высоких нагрузках. Следовательно, трафик должен быть разделён для обеспечения эффективности передачи в условиях высокой интенсивности потока данных.

# %%
import queue
import time

class Packet:
    def __init__(self, size, info):
        self.size = size
        self.info = info

    def __repr__(self):
        return f"Packet(size={self.size}, info={self.info})"

def process_queue(queue, index):
    while not queue.empty():
        packet = queue.get()
        print(f'Working on {packet} in Queue#{index}')
        time.sleep(0.1)
        print(f'Finished {packet} Queue#{index} Size: {packet.size}')
        # q.task_done()

def process_all_queues(queues):
    for index, q in enumerate(queues):
        process_queue(q, index)

queues = [queue.Queue() for _ in range(10)]

for item in range(10):
    for q in queues:
        packet = Packet(size=100, info=f'info_{item}')
        q.put(packet)

start = time.time()
process_all_queues(queues)
end = time.time()
print(f'All work completed in {end-start} seconds')
# Out:
# Working on Packet(size=100, info=info_0) in Queue#0
# Finished Packet(size=100, info=info_0) Queue#0 Size: 100
# Working on Packet(size=100, info=info_1) in Queue#0
# Finished Packet(size=100, info=info_1) Queue#0 Size: 100
# Working on Packet(size=100, info=info_2) in Queue#0
# Finished Packet(size=100, info=info_2) Queue#0 Size: 100
# Working on Packet(size=100, info=info_3) in Queue#0
# Finished Packet(size=100, info=info_3) Queue#0 Size: 100
# Working on Packet(size=100, info=info_4) in Queue#0
# Finished Packet(size=100, info=info_4) Queue#0 Size: 100
# Working on Packet(size=100, info=info_5) in Queue#0
# Finished Packet(size=100, info=info_5) Queue#0 Size: 100
# Working on Packet(size=100, info=info_6) in Queue#0
# Finished Packet(size=100, info=info_6) Queue#0 Size: 100
# Working on Packet(size=100, info=info_7) in Queue#0
# Finished Packet(size=100, info=info_7) Queue#0 Size: 100
# Working on Packet(size=100, info=info_8) in Queue#0
# Finished Packet(size=100, info=info_8) Queue#0 Size: 100
# Working on Packet(size=100, info=info_9) in Queue#0
# Finished Packet(size=100, info=info_9) Queue#0 Size: 100
# Working on Packet(size=100, info=info_0) in Queue#1
# Finished Packet(size=100, info=info_0) Queue#1 Size: 100
# Working on Packet(size=100, info=info_1) in Queue#1
# Finished Packet(size=100, info=info_1) Queue#1 Size: 100
# Working on Packet(size=100, info=info_2) in Queue#1
# Finished Packet(size=100, info=info_2) Queue#1 Size: 100
# Working on Packet(size=100, info=info_3) in Queue#1
# Finished Packet(size=100, info=info_3) Queue#1 Size: 100
# Working on Packet(size=100, info=info_4) in Queue#1
# Finished Packet(size=100, info=info_4) Queue#1 Size: 100
# Working on Packet(size=100, info=info_5) in Queue#1
# Finished Packet(size=100, info=info_5) Queue#1 Size: 100
# Working on Packet(size=100, info=info_6) in Queue#1
# Finished Packet(size=100, info=info_6) Queue#1 Size: 100
# Working on Packet(size=100, info=info_7) in Queue#1
# Finished Packet(size=100, info=info_7) Queue#1 Size: 100
# Working on Packet(size=100, info=info_8) in Queue#1
# Finished Packet(size=100, info=info_8) Queue#1 Size: 100
# Working on Packet(size=100, info=info_9) in Queue#1
# Finished Packet(size=100, info=info_9) Queue#1 Size: 100
# Working on Packet(size=100, info=info_0) in Queue#2
# Finished Packet(size=100, info=info_0) Queue#2 Size: 100
# Working on Packet(size=100, info=info_1) in Queue#2
# Finished Packet(size=100, info=info_1) Queue#2 Size: 100
# Working on Packet(size=100, info=info_2) in Queue#2
# Finished Packet(size=100, info=info_2) Queue#2 Size: 100
# Working on Packet(size=100, info=info_3) in Queue#2
# Finished Packet(size=100, info=info_3) Queue#2 Size: 100
# Working on Packet(size=100, info=info_4) in Queue#2
# Finished Packet(size=100, info=info_4) Queue#2 Size: 100
# Working on Packet(size=100, info=info_5) in Queue#2
# Finished Packet(size=100, info=info_5) Queue#2 Size: 100
# Working on Packet(size=100, info=info_6) in Queue#2
# Finished Packet(size=100, info=info_6) Queue#2 Size: 100
# Working on Packet(size=100, info=info_7) in Queue#2
# Finished Packet(size=100, info=info_7) Queue#2 Size: 100
# Working on Packet(size=100, info=info_8) in Queue#2
# Finished Packet(size=100, info=info_8) Queue#2 Size: 100
# Working on Packet(size=100, info=info_9) in Queue#2
# Finished Packet(size=100, info=info_9) Queue#2 Size: 100
# Working on Packet(size=100, info=info_0) in Queue#3
# Finished Packet(size=100, info=info_0) Queue#3 Size: 100
# Working on Packet(size=100, info=info_1) in Queue#3
# Finished Packet(size=100, info=info_1) Queue#3 Size: 100
# Working on Packet(size=100, info=info_2) in Queue#3
# Finished Packet(size=100, info=info_2) Queue#3 Size: 100
# Working on Packet(size=100, info=info_3) in Queue#3
# Finished Packet(size=100, info=info_3) Queue#3 Size: 100
# Working on Packet(size=100, info=info_4) in Queue#3
# Finished Packet(size=100, info=info_4) Queue#3 Size: 100
# Working on Packet(size=100, info=info_5) in Queue#3
# Finished Packet(size=100, info=info_5) Queue#3 Size: 100
# Working on Packet(size=100, info=info_6) in Queue#3
# Finished Packet(size=100, info=info_6) Queue#3 Size: 100
# Working on Packet(size=100, info=info_7) in Queue#3
# Finished Packet(size=100, info=info_7) Queue#3 Size: 100
# Working on Packet(size=100, info=info_8) in Queue#3
# Finished Packet(size=100, info=info_8) Queue#3 Size: 100
# Working on Packet(size=100, info=info_9) in Queue#3
# Finished Packet(size=100, info=info_9) Queue#3 Size: 100
# Working on Packet(size=100, info=info_0) in Queue#4
# Finished Packet(size=100, info=info_0) Queue#4 Size: 100
# Working on Packet(size=100, info=info_1) in Queue#4
# Finished Packet(size=100, info=info_1) Queue#4 Size: 100
# Working on Packet(size=100, info=info_2) in Queue#4
# Finished Packet(size=100, info=info_2) Queue#4 Size: 100
# Working on Packet(size=100, info=info_3) in Queue#4
# Finished Packet(size=100, info=info_3) Queue#4 Size: 100
# Working on Packet(size=100, info=info_4) in Queue#4
# Finished Packet(size=100, info=info_4) Queue#4 Size: 100
# Working on Packet(size=100, info=info_5) in Queue#4
# Finished Packet(size=100, info=info_5) Queue#4 Size: 100
# Working on Packet(size=100, info=info_6) in Queue#4
# Finished Packet(size=100, info=info_6) Queue#4 Size: 100
# Working on Packet(size=100, info=info_7) in Queue#4
# Finished Packet(size=100, info=info_7) Queue#4 Size: 100
# Working on Packet(size=100, info=info_8) in Queue#4
# Finished Packet(size=100, info=info_8) Queue#4 Size: 100
# Working on Packet(size=100, info=info_9) in Queue#4
# Finished Packet(size=100, info=info_9) Queue#4 Size: 100
# Working on Packet(size=100, info=info_0) in Queue#5
# Finished Packet(size=100, info=info_0) Queue#5 Size: 100
# Working on Packet(size=100, info=info_1) in Queue#5
# Finished Packet(size=100, info=info_1) Queue#5 Size: 100
# Working on Packet(size=100, info=info_2) in Queue#5
# Finished Packet(size=100, info=info_2) Queue#5 Size: 100
# Working on Packet(size=100, info=info_3) in Queue#5
# Finished Packet(size=100, info=info_3) Queue#5 Size: 100
# Working on Packet(size=100, info=info_4) in Queue#5
# Finished Packet(size=100, info=info_4) Queue#5 Size: 100
# Working on Packet(size=100, info=info_5) in Queue#5
# Finished Packet(size=100, info=info_5) Queue#5 Size: 100
# Working on Packet(size=100, info=info_6) in Queue#5
# Finished Packet(size=100, info=info_6) Queue#5 Size: 100
# Working on Packet(size=100, info=info_7) in Queue#5
# Finished Packet(size=100, info=info_7) Queue#5 Size: 100
# Working on Packet(size=100, info=info_8) in Queue#5
# Finished Packet(size=100, info=info_8) Queue#5 Size: 100
# Working on Packet(size=100, info=info_9) in Queue#5
# Finished Packet(size=100, info=info_9) Queue#5 Size: 100
# Working on Packet(size=100, info=info_0) in Queue#6
# Finished Packet(size=100, info=info_0) Queue#6 Size: 100
# Working on Packet(size=100, info=info_1) in Queue#6
# Finished Packet(size=100, info=info_1) Queue#6 Size: 100
# Working on Packet(size=100, info=info_2) in Queue#6
# Finished Packet(size=100, info=info_2) Queue#6 Size: 100
# Working on Packet(size=100, info=info_3) in Queue#6
# Finished Packet(size=100, info=info_3) Queue#6 Size: 100
# Working on Packet(size=100, info=info_4) in Queue#6
# Finished Packet(size=100, info=info_4) Queue#6 Size: 100
# Working on Packet(size=100, info=info_5) in Queue#6
# Finished Packet(size=100, info=info_5) Queue#6 Size: 100
# Working on Packet(size=100, info=info_6) in Queue#6
# Finished Packet(size=100, info=info_6) Queue#6 Size: 100
# Working on Packet(size=100, info=info_7) in Queue#6
# Finished Packet(size=100, info=info_7) Queue#6 Size: 100
# Working on Packet(size=100, info=info_8) in Queue#6
# Finished Packet(size=100, info=info_8) Queue#6 Size: 100
# Working on Packet(size=100, info=info_9) in Queue#6
# Finished Packet(size=100, info=info_9) Queue#6 Size: 100
# Working on Packet(size=100, info=info_0) in Queue#7
# Finished Packet(size=100, info=info_0) Queue#7 Size: 100
# Working on Packet(size=100, info=info_1) in Queue#7
# Finished Packet(size=100, info=info_1) Queue#7 Size: 100
# Working on Packet(size=100, info=info_2) in Queue#7
# Finished Packet(size=100, info=info_2) Queue#7 Size: 100
# Working on Packet(size=100, info=info_3) in Queue#7
# Finished Packet(size=100, info=info_3) Queue#7 Size: 100
# Working on Packet(size=100, info=info_4) in Queue#7
# Finished Packet(size=100, info=info_4) Queue#7 Size: 100
# Working on Packet(size=100, info=info_5) in Queue#7
# Finished Packet(size=100, info=info_5) Queue#7 Size: 100
# Working on Packet(size=100, info=info_6) in Queue#7
# Finished Packet(size=100, info=info_6) Queue#7 Size: 100
# Working on Packet(size=100, info=info_7) in Queue#7
# Finished Packet(size=100, info=info_7) Queue#7 Size: 100
# Working on Packet(size=100, info=info_8) in Queue#7
# Finished Packet(size=100, info=info_8) Queue#7 Size: 100
# Working on Packet(size=100, info=info_9) in Queue#7
# Finished Packet(size=100, info=info_9) Queue#7 Size: 100
# Working on Packet(size=100, info=info_0) in Queue#8
# Finished Packet(size=100, info=info_0) Queue#8 Size: 100
# Working on Packet(size=100, info=info_1) in Queue#8
# Finished Packet(size=100, info=info_1) Queue#8 Size: 100
# Working on Packet(size=100, info=info_2) in Queue#8
# Finished Packet(size=100, info=info_2) Queue#8 Size: 100
# Working on Packet(size=100, info=info_3) in Queue#8
# Finished Packet(size=100, info=info_3) Queue#8 Size: 100
# Working on Packet(size=100, info=info_4) in Queue#8
# Finished Packet(size=100, info=info_4) Queue#8 Size: 100
# Working on Packet(size=100, info=info_5) in Queue#8
# Finished Packet(size=100, info=info_5) Queue#8 Size: 100
# Working on Packet(size=100, info=info_6) in Queue#8
# Finished Packet(size=100, info=info_6) Queue#8 Size: 100
# Working on Packet(size=100, info=info_7) in Queue#8
# Finished Packet(size=100, info=info_7) Queue#8 Size: 100
# Working on Packet(size=100, info=info_8) in Queue#8
# Finished Packet(size=100, info=info_8) Queue#8 Size: 100
# Working on Packet(size=100, info=info_9) in Queue#8
# Finished Packet(size=100, info=info_9) Queue#8 Size: 100
# Working on Packet(size=100, info=info_0) in Queue#9
# Finished Packet(size=100, info=info_0) Queue#9 Size: 100
# Working on Packet(size=100, info=info_1) in Queue#9
# Finished Packet(size=100, info=info_1) Queue#9 Size: 100
# Working on Packet(size=100, info=info_2) in Queue#9
# Finished Packet(size=100, info=info_2) Queue#9 Size: 100
# Working on Packet(size=100, info=info_3) in Queue#9
# Finished Packet(size=100, info=info_3) Queue#9 Size: 100
# Working on Packet(size=100, info=info_4) in Queue#9
# Finished Packet(size=100, info=info_4) Queue#9 Size: 100
# Working on Packet(size=100, info=info_5) in Queue#9
# Finished Packet(size=100, info=info_5) Queue#9 Size: 100
# Working on Packet(size=100, info=info_6) in Queue#9
# Finished Packet(size=100, info=info_6) Queue#9 Size: 100
# Working on Packet(size=100, info=info_7) in Queue#9
# Finished Packet(size=100, info=info_7) Queue#9 Size: 100
# Working on Packet(size=100, info=info_8) in Queue#9
# Finished Packet(size=100, info=info_8) Queue#9 Size: 100
# Working on Packet(size=100, info=info_9) in Queue#9
# Finished Packet(size=100, info=info_9) Queue#9 Size: 100
# All work completed in 10.04246711730957 seconds

# %%
q = queue.Queue()

for item in range(100):
        packet = Packet(size=100, info=f'info_{item}')
        q.put(packet)

start = time.time()
process_queue(q,0)
end = time.time()
print(f'All work completed in {end-start} seconds')
# Out:
# Working on Packet(size=100, info=info_0) in Queue#0
# Finished Packet(size=100, info=info_0) Queue#0 Size: 100
# Working on Packet(size=100, info=info_1) in Queue#0
# Finished Packet(size=100, info=info_1) Queue#0 Size: 100
# Working on Packet(size=100, info=info_2) in Queue#0
# Finished Packet(size=100, info=info_2) Queue#0 Size: 100
# Working on Packet(size=100, info=info_3) in Queue#0
# Finished Packet(size=100, info=info_3) Queue#0 Size: 100
# Working on Packet(size=100, info=info_4) in Queue#0
# Finished Packet(size=100, info=info_4) Queue#0 Size: 100
# Working on Packet(size=100, info=info_5) in Queue#0
# Finished Packet(size=100, info=info_5) Queue#0 Size: 100
# Working on Packet(size=100, info=info_6) in Queue#0
# Finished Packet(size=100, info=info_6) Queue#0 Size: 100
# Working on Packet(size=100, info=info_7) in Queue#0
# Finished Packet(size=100, info=info_7) Queue#0 Size: 100
# Working on Packet(size=100, info=info_8) in Queue#0
# Finished Packet(size=100, info=info_8) Queue#0 Size: 100
# Working on Packet(size=100, info=info_9) in Queue#0
# Finished Packet(size=100, info=info_9) Queue#0 Size: 100
# Working on Packet(size=100, info=info_10) in Queue#0
# Finished Packet(size=100, info=info_10) Queue#0 Size: 100
# Working on Packet(size=100, info=info_11) in Queue#0
# Finished Packet(size=100, info=info_11) Queue#0 Size: 100
# Working on Packet(size=100, info=info_12) in Queue#0
# Finished Packet(size=100, info=info_12) Queue#0 Size: 100
# Working on Packet(size=100, info=info_13) in Queue#0
# Finished Packet(size=100, info=info_13) Queue#0 Size: 100
# Working on Packet(size=100, info=info_14) in Queue#0
# Finished Packet(size=100, info=info_14) Queue#0 Size: 100
# Working on Packet(size=100, info=info_15) in Queue#0
# Finished Packet(size=100, info=info_15) Queue#0 Size: 100
# Working on Packet(size=100, info=info_16) in Queue#0
# Finished Packet(size=100, info=info_16) Queue#0 Size: 100
# Working on Packet(size=100, info=info_17) in Queue#0
# Finished Packet(size=100, info=info_17) Queue#0 Size: 100
# Working on Packet(size=100, info=info_18) in Queue#0
# Finished Packet(size=100, info=info_18) Queue#0 Size: 100
# Working on Packet(size=100, info=info_19) in Queue#0
# Finished Packet(size=100, info=info_19) Queue#0 Size: 100
# Working on Packet(size=100, info=info_20) in Queue#0
# Finished Packet(size=100, info=info_20) Queue#0 Size: 100
# Working on Packet(size=100, info=info_21) in Queue#0
# Finished Packet(size=100, info=info_21) Queue#0 Size: 100
# Working on Packet(size=100, info=info_22) in Queue#0
# Finished Packet(size=100, info=info_22) Queue#0 Size: 100
# Working on Packet(size=100, info=info_23) in Queue#0
# Finished Packet(size=100, info=info_23) Queue#0 Size: 100
# Working on Packet(size=100, info=info_24) in Queue#0
# Finished Packet(size=100, info=info_24) Queue#0 Size: 100
# Working on Packet(size=100, info=info_25) in Queue#0
# Finished Packet(size=100, info=info_25) Queue#0 Size: 100
# Working on Packet(size=100, info=info_26) in Queue#0
# Finished Packet(size=100, info=info_26) Queue#0 Size: 100
# Working on Packet(size=100, info=info_27) in Queue#0
# Finished Packet(size=100, info=info_27) Queue#0 Size: 100
# Working on Packet(size=100, info=info_28) in Queue#0
# Finished Packet(size=100, info=info_28) Queue#0 Size: 100
# Working on Packet(size=100, info=info_29) in Queue#0
# Finished Packet(size=100, info=info_29) Queue#0 Size: 100
# Working on Packet(size=100, info=info_30) in Queue#0
# Finished Packet(size=100, info=info_30) Queue#0 Size: 100
# Working on Packet(size=100, info=info_31) in Queue#0
# Finished Packet(size=100, info=info_31) Queue#0 Size: 100
# Working on Packet(size=100, info=info_32) in Queue#0
# Finished Packet(size=100, info=info_32) Queue#0 Size: 100
# Working on Packet(size=100, info=info_33) in Queue#0
# Finished Packet(size=100, info=info_33) Queue#0 Size: 100
# Working on Packet(size=100, info=info_34) in Queue#0
# Finished Packet(size=100, info=info_34) Queue#0 Size: 100
# Working on Packet(size=100, info=info_35) in Queue#0
# Finished Packet(size=100, info=info_35) Queue#0 Size: 100
# Working on Packet(size=100, info=info_36) in Queue#0
# Finished Packet(size=100, info=info_36) Queue#0 Size: 100
# Working on Packet(size=100, info=info_37) in Queue#0
# Finished Packet(size=100, info=info_37) Queue#0 Size: 100
# Working on Packet(size=100, info=info_38) in Queue#0
# Finished Packet(size=100, info=info_38) Queue#0 Size: 100
# Working on Packet(size=100, info=info_39) in Queue#0
# Finished Packet(size=100, info=info_39) Queue#0 Size: 100
# Working on Packet(size=100, info=info_40) in Queue#0
# Finished Packet(size=100, info=info_40) Queue#0 Size: 100
# Working on Packet(size=100, info=info_41) in Queue#0
# Finished Packet(size=100, info=info_41) Queue#0 Size: 100
# Working on Packet(size=100, info=info_42) in Queue#0
# Finished Packet(size=100, info=info_42) Queue#0 Size: 100
# Working on Packet(size=100, info=info_43) in Queue#0
# Finished Packet(size=100, info=info_43) Queue#0 Size: 100
# Working on Packet(size=100, info=info_44) in Queue#0
# Finished Packet(size=100, info=info_44) Queue#0 Size: 100
# Working on Packet(size=100, info=info_45) in Queue#0
# Finished Packet(size=100, info=info_45) Queue#0 Size: 100
# Working on Packet(size=100, info=info_46) in Queue#0
# Finished Packet(size=100, info=info_46) Queue#0 Size: 100
# Working on Packet(size=100, info=info_47) in Queue#0
# Finished Packet(size=100, info=info_47) Queue#0 Size: 100
# Working on Packet(size=100, info=info_48) in Queue#0
# Finished Packet(size=100, info=info_48) Queue#0 Size: 100
# Working on Packet(size=100, info=info_49) in Queue#0
# Finished Packet(size=100, info=info_49) Queue#0 Size: 100
# Working on Packet(size=100, info=info_50) in Queue#0
# Finished Packet(size=100, info=info_50) Queue#0 Size: 100
# Working on Packet(size=100, info=info_51) in Queue#0
# Finished Packet(size=100, info=info_51) Queue#0 Size: 100
# Working on Packet(size=100, info=info_52) in Queue#0
# Finished Packet(size=100, info=info_52) Queue#0 Size: 100
# Working on Packet(size=100, info=info_53) in Queue#0
# Finished Packet(size=100, info=info_53) Queue#0 Size: 100
# Working on Packet(size=100, info=info_54) in Queue#0
# Finished Packet(size=100, info=info_54) Queue#0 Size: 100
# Working on Packet(size=100, info=info_55) in Queue#0
# Finished Packet(size=100, info=info_55) Queue#0 Size: 100
# Working on Packet(size=100, info=info_56) in Queue#0
# Finished Packet(size=100, info=info_56) Queue#0 Size: 100
# Working on Packet(size=100, info=info_57) in Queue#0
# Finished Packet(size=100, info=info_57) Queue#0 Size: 100
# Working on Packet(size=100, info=info_58) in Queue#0
# Finished Packet(size=100, info=info_58) Queue#0 Size: 100
# Working on Packet(size=100, info=info_59) in Queue#0
# Finished Packet(size=100, info=info_59) Queue#0 Size: 100
# Working on Packet(size=100, info=info_60) in Queue#0
# Finished Packet(size=100, info=info_60) Queue#0 Size: 100
# Working on Packet(size=100, info=info_61) in Queue#0
# Finished Packet(size=100, info=info_61) Queue#0 Size: 100
# Working on Packet(size=100, info=info_62) in Queue#0
# Finished Packet(size=100, info=info_62) Queue#0 Size: 100
# Working on Packet(size=100, info=info_63) in Queue#0
# Finished Packet(size=100, info=info_63) Queue#0 Size: 100
# Working on Packet(size=100, info=info_64) in Queue#0
# Finished Packet(size=100, info=info_64) Queue#0 Size: 100
# Working on Packet(size=100, info=info_65) in Queue#0
# Finished Packet(size=100, info=info_65) Queue#0 Size: 100
# Working on Packet(size=100, info=info_66) in Queue#0
# Finished Packet(size=100, info=info_66) Queue#0 Size: 100
# Working on Packet(size=100, info=info_67) in Queue#0
# Finished Packet(size=100, info=info_67) Queue#0 Size: 100
# Working on Packet(size=100, info=info_68) in Queue#0
# Finished Packet(size=100, info=info_68) Queue#0 Size: 100
# Working on Packet(size=100, info=info_69) in Queue#0
# Finished Packet(size=100, info=info_69) Queue#0 Size: 100
# Working on Packet(size=100, info=info_70) in Queue#0
# Finished Packet(size=100, info=info_70) Queue#0 Size: 100
# Working on Packet(size=100, info=info_71) in Queue#0
# Finished Packet(size=100, info=info_71) Queue#0 Size: 100
# Working on Packet(size=100, info=info_72) in Queue#0
# Finished Packet(size=100, info=info_72) Queue#0 Size: 100
# Working on Packet(size=100, info=info_73) in Queue#0
# Finished Packet(size=100, info=info_73) Queue#0 Size: 100
# Working on Packet(size=100, info=info_74) in Queue#0
# Finished Packet(size=100, info=info_74) Queue#0 Size: 100
# Working on Packet(size=100, info=info_75) in Queue#0
# Finished Packet(size=100, info=info_75) Queue#0 Size: 100
# Working on Packet(size=100, info=info_76) in Queue#0
# Finished Packet(size=100, info=info_76) Queue#0 Size: 100
# Working on Packet(size=100, info=info_77) in Queue#0
# Finished Packet(size=100, info=info_77) Queue#0 Size: 100
# Working on Packet(size=100, info=info_78) in Queue#0
# Finished Packet(size=100, info=info_78) Queue#0 Size: 100
# Working on Packet(size=100, info=info_79) in Queue#0
# Finished Packet(size=100, info=info_79) Queue#0 Size: 100
# Working on Packet(size=100, info=info_80) in Queue#0
# Finished Packet(size=100, info=info_80) Queue#0 Size: 100
# Working on Packet(size=100, info=info_81) in Queue#0
# Finished Packet(size=100, info=info_81) Queue#0 Size: 100
# Working on Packet(size=100, info=info_82) in Queue#0
# Finished Packet(size=100, info=info_82) Queue#0 Size: 100
# Working on Packet(size=100, info=info_83) in Queue#0
# Finished Packet(size=100, info=info_83) Queue#0 Size: 100
# Working on Packet(size=100, info=info_84) in Queue#0
# Finished Packet(size=100, info=info_84) Queue#0 Size: 100
# Working on Packet(size=100, info=info_85) in Queue#0
# Finished Packet(size=100, info=info_85) Queue#0 Size: 100
# Working on Packet(size=100, info=info_86) in Queue#0
# Finished Packet(size=100, info=info_86) Queue#0 Size: 100
# Working on Packet(size=100, info=info_87) in Queue#0
# Finished Packet(size=100, info=info_87) Queue#0 Size: 100
# Working on Packet(size=100, info=info_88) in Queue#0
# Finished Packet(size=100, info=info_88) Queue#0 Size: 100
# Working on Packet(size=100, info=info_89) in Queue#0
# Finished Packet(size=100, info=info_89) Queue#0 Size: 100
# Working on Packet(size=100, info=info_90) in Queue#0
# Finished Packet(size=100, info=info_90) Queue#0 Size: 100
# Working on Packet(size=100, info=info_91) in Queue#0
# Finished Packet(size=100, info=info_91) Queue#0 Size: 100
# Working on Packet(size=100, info=info_92) in Queue#0
# Finished Packet(size=100, info=info_92) Queue#0 Size: 100
# Working on Packet(size=100, info=info_93) in Queue#0
# Finished Packet(size=100, info=info_93) Queue#0 Size: 100
# Working on Packet(size=100, info=info_94) in Queue#0
# Finished Packet(size=100, info=info_94) Queue#0 Size: 100
# Working on Packet(size=100, info=info_95) in Queue#0
# Finished Packet(size=100, info=info_95) Queue#0 Size: 100
# Working on Packet(size=100, info=info_96) in Queue#0
# Finished Packet(size=100, info=info_96) Queue#0 Size: 100
# Working on Packet(size=100, info=info_97) in Queue#0
# Finished Packet(size=100, info=info_97) Queue#0 Size: 100
# Working on Packet(size=100, info=info_98) in Queue#0
# Finished Packet(size=100, info=info_98) Queue#0 Size: 100
# Working on Packet(size=100, info=info_99) in Queue#0
# Finished Packet(size=100, info=info_99) Queue#0 Size: 100
# All work completed in 10.050948858261108 seconds
